# %% [markdown]
# <a href="https://colab.research.google.com/github/omarreess/DLI-Internship-Data-Science/blob/main/Assignment%2012%20-%20PCA%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <H1> <center> Trying PCA with Data's Features

# %% [markdown]
# <H1> Importing

# %%
import numpy as np
import matplotlib.pyplot as plt 
from keras.datasets import mnist
from sklearn.decomposition import PCA
from sklearn.decomposition import KernelPCA
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import confusion_matrix
import seaborn as sns
from matplotlib import rcParams
from sklearn.metrics import precision_recall_fscore_support 
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# <H1> Handling Data

# %%
# Getting Data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train1.reshape(X_train.shape[0],-1) 
X_test = X_test.reshape(X_test.shape[0],-1)


# Sampling in balanced way
classes = dict()
for i in range(len(np.unique(y_train))): 
 classes[i] = np.where(y_train == i)[0]
 
X_train_sample = [] 
y_train_sample = [] 

for key in classes:
 length = round(len(classes[key]) / 20) 
 for i,index in enumerate(classes[key]):
  if i >= length: break
  else:
   X_train_sample.append(X_train[index]) 
   y_train_sample.append(y_train[index])

# %% [markdown]
# <H1> Applying PCA with Kernel on Data's Features

# %%
# PCA
 
pca = PCA(n_components = 0.9) 
pca.fit(X_train)
X_train_pca = pca.transform(X_train) 
X_test_pca = pca.transform(X_test)

## Kernel PCA
kernel = KernelPCA(kernel='poly', degree=2) 
kernel.fit(X_train_sample)
X_train_kernel = kernel.transform(X_train) 
X_test_kernel = kernel.transform(X_test)

pca.fit(X_train_kernel)
X_train_kpca = pca.transform(X_train_kernel) 
X_test_kpca = pca.transform(X_test_kernel)
 


print(f'Number of features before reduction: {len(X_train[0])}') 
print(f'Number of features after PCA reduction: {len(X_train_pca[0])}') 
print(f'Number of features after Kernel PCA: {len(X_train_kernel[0])}')
print(f'Number of features after Kernel PCA and PCA reduction: {len(X_train_kpca[0])}')
# Out:
# Number of features before reduction: 784
# Number of features after PCA reduction: 87
# Number of features after Kernel PCA: 2999
# Number of features after Kernel PCA and PCA reduction: 362

# %% [markdown]
# <H1> Plotting Data with PCA Edit

# %%
plt.hist(X_train) 
plt.xlabel('Values') 
plt.ylabel('Number of samples')
plt.title('Features distribution histogram') 
plt.show()


plt.hist(X_train_pca) 
plt.xlabel('Values') 
plt.ylabel('Number of samples')
plt.title('PCA features distribution histogram') 
plt.show()

plt.hist(X_train_kernel) 
plt.xlabel('Values') 
plt.ylabel('Number of samples')
plt.title('Kernel features distribution histogram') 
plt.show()


plt.hist(X_train_kpca) 
plt.xlabel('Values')
plt.ylabel('Number of samples')
plt.title('Kernel PCA features distribution histogram') 
plt.show()
